# %% [markdown]
# ### Setup

# %%
pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\kevin\anaconda3\lib\site-packages (2.9.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
from psycopg2.extras import execute_values

# %%
df = pd.read_csv('car_prices.csv')

# %%
# Pass the connection string to a variable, conn_url
conn_url = 'postgresql://postgres:123@localhost/APAN5400'

# Create an engine that connects to PostgreSQL server
engine = create_engine(conn_url)

print('Connecting to the PostgreSQL database...')
conn = psycopg2.connect(
    host="localhost",
    port='5432',
    dbname="APAN5400",
    user="postgres",
    password="123")

# Create a cursor
cur = conn.cursor()
# Out:
# Connecting to the PostgreSQL database...

# %% [markdown]
# ### Create table

# %%
# Execute a statement
print('PostgreSQL database version:')
cur.execute('SELECT version()')

# Display the PostgreSQL database server version
db_version = cur.fetchone()
print(db_version)
# Out:
# PostgreSQL database version:
# ('PostgreSQL 16.2 (Debian 16.2-1.pgdg120+2) on x86_64-pc-linux-gnu, compiled by gcc (Debian 12.2.0-14) 12.2.0, 64-bit',)

# %%
stmt = """
    DROP TABLE vehicles CASCADE;
    DROP TABLE sales CASCADE;
    CREATE TABLE vehicles(
        vehicle_id int PRIMARY KEY,
        year int NOT NULL,
        make varchar(50),
        model varchar(50),
        trim varchar(50),
        body varchar(50),
        transmission varchar(50),
        state char(2) NOT NULL,
        condition double precision,
        odometer double precision,
        color varchar(50),
        interior varchar(50),
        MMR double precision
    );
    
    CREATE TABLE sales(
        sale_id int,
        vehicle_id int,
        state char(2) NOT NULL,
        seller varchar(50) NOT NULL,
        selling_price double precision,
        sale_date date NOT NULL,
        PRIMARY KEY (sale_id, vehicle_id),
        FOREIGN KEY (vehicle_id) REFERENCES vehicles(vehicle_id)
    );
    """

# %%
cur.execute(stmt)
conn.commit()

# %% [markdown]
# ### Clean the data

# %%
# Drop the original id column 'vin'
df.drop(columns=['vin'], inplace=True)

# %%
# Change column names
df = df.rename(columns={"sellingprice": "selling_price", "saledate": "sale_date"})

# %%
# Clean 'sale_date' column
df['sale_date'] = df['sale_date'].str.replace("GMT-0800 (PST)", "")
df['sale_date'] = pd.to_datetime(df['sale_date'], errors='coerce')
df['sale_date'] = df['sale_date'].dt.strftime('%m/%d/%Y')

# %%
# Drop NA values
df.dropna(subset=['sale_date'], inplace=True)

# %%
# Adjust the 'state' column to upper case
df['state'] = df['state'].str.upper()

# %%
# Add vehicle_id
df.insert(0, 'vehicle_id', range(1, 1 + len(df)))

# %% [markdown]
# ### Split the table into vehicles and sales

# %%
vehicles_df = df[['vehicle_id','year','make','model','trim','body','transmission','state','condition','odometer','color','interior','mmr']]
sales_df = df[['vehicle_id','state','seller','selling_price','sale_date']]

# %%
vehicles_df.head()
# Out:
#    vehicle_id  year   make                model        trim   body  \
# 0           1  2015    Kia              Sorento          LX    SUV
# 1           2  2015    Kia              Sorento          LX    SUV
# 2           3  2014    BMW             3 Series  328i SULEV  Sedan
# 3           4  2015  Volvo                  S60          T5  Sedan
# 4           5  2014    BMW  6 Series Gran Coupe        650i  Sedan
#
#   transmission state  condition  odometer  color interior      mmr
# 0    automatic    CA        5.0   16639.0  white    black  20500.0
# 1    automatic    CA        5.0    9393.0  white    beige  20800.0
# 2    automatic    CA       45.0    1331.0   gray    black  31900.0
# 3    automatic    CA       41.0   14282.0  white    black  27500.0
# 4    automatic    CA       43.0    2641.0   gray    black  66000.0

# %%
# Add sale_id
sales_df.insert(0, 'sale_id', range(1, 1 + len(sales_df)))

# %%
sales_df.head()
# Out:
#    sale_id  vehicle_id state                                  seller  \
# 0        1           1    CA                 kia motors america  inc
# 1        2           2    CA                 kia motors america  inc
# 2        3           3    CA  financial services remarketing (lease)
# 3        4           4    CA                 volvo na rep/world omni
# 4        5           5    CA  financial services remarketing (lease)
#
#    selling_price   sale_date
# 0        21500.0  12/16/2014
# 1        21500.0  12/16/2014
# 2        30000.0  01/15/2015
# 3        27750.0  01/29/2015
# 4        67000.0  12/18/2014

# %% [markdown]
# #### Insert data into 'vahicles' table

# %%
insert = """
        INSERT INTO vehicles(vehicle_id, year, make, model, trim, body, transmission,
                            state, condition, odometer, color, interior, mmr) VALUES %s
        """

# %%
vehicles_data = list(vehicles_df.itertuples(index=False, name=None))
execute_values(cur, insert, vehicles_data)
conn.commit()

# %% [markdown]
# #### Insert data into 'sales' table

# %%
insert = """
        INSERT INTO sales(sale_id, vehicle_id, state, seller, selling_price, sale_date) VALUES %s
        """

# %%
sales_data = list(sales_df.itertuples(index=False, name=None))
execute_values(cur, insert, sales_data)
conn.commit()

# %% [markdown]
# ### Total vehicle production each year

# %%
query = """
        SELECT year, COUNT(vehicle_id) AS total_production
        FROM vehicles
        GROUP BY year;
        """

result_df = pd.read_sql_query(query, engine)
result_df
# Out:
#     year  total_production
# 0   1991                54
# 1   1989                16
# 2   1983                 1
# 3   2009             15169
# 4   2013             63215
# 5   2003             10353
# 6   1997              1211
# 7   1994               318
# 8   2014             55681
# 9   1987                 6
# 10  2000              4102
# 11  1985                 6
# 12  2006             20414
# 13  2012             69756
# 14  1988                11
# 15  2008             23379
# 16  1984                 5
# 17  2005             16573
# 18  2015              3604
# 19  1990                39
# 20  1993               167
# 21  2002              7602
# 22  2004             13428
# 23  1986                 8
# 24  1982                 1
# 25  1995               584
# 26  1992               108
# 27  2010             19184
# 28  1996               699
# 29  2011             37380
# 30  1998              1700
# 31  2007             23010
# 32  2001              5035
# 33  1999              2670

# %% [markdown]
# ### Top 10 model that sold the most units over time

# %%
query = """
        SELECT model, COUNT(vehicle_id) AS model_count
        FROM vehicles
        GROUP BY model
        HAVING COUNT(vehicle_id) > 1000
        ORDER BY model_count DESC
        LIMIT 10;
        """

result_df = pd.read_sql_query(query, engine)
result_df
# Out:
#            model  model_count
# 0         Altima        14094
# 1          F-150        10294
# 2         Fusion         8970
# 3         Escape         8415
# 4          Camry         8389
# 5          Focus         7596
# 6            NaN         7072
# 7         Accord         6849
# 8  Grand Caravan         5993
# 9       3 Series         5778

# %% [markdown]
# ### Top 10 brand (make) that generated the most total sales

# %%
query = """
        SELECT v.make, SUM(s.selling_price) AS total_sales
        FROM sales s
        JOIN vehicles v ON s.vehicle_id = v.vehicle_id
        GROUP BY v.make
        ORDER BY total_sales DESC
        LIMIT 10;
        """

result_df = pd.read_sql_query(query, engine)
result_df
# Out:
#             make  total_sales
# 0           Ford  950437524.0
# 1      Chevrolet  505735074.0
# 2         Nissan  425751288.0
# 3         Toyota  328448011.0
# 4            BMW  290019040.0
# 5  Mercedes-Benz  244670243.0
# 6          Dodge  241602156.0
# 7          Honda  224441549.0
# 8       Infiniti  213406451.0
# 9          Lexus  164497255.0

# %% [markdown]
# ### The total units and total sales Nissan, Toyota, and Honda sold each year.

# %%
query = """
        SELECT 
            v.make, 
            year, 
            COUNT(*) AS total_sold_units,
            SUM(s.selling_price) AS total_sales
        FROM sales s
        JOIN vehicles v ON s.vehicle_id = v.vehicle_id
        WHERE v.make IN ('Nissan', 'Toyota', 'Honda')
        GROUP BY v.make, v.year
        ORDER BY v.make, v.year;
        """

result_df = pd.read_sql_query(query, engine)
pd.set_option('display.max_rows', None)
result_df
# Out:
#       make  year  total_sold_units  total_sales
# 0    Honda  1990                 6       2800.0
# 1    Honda  1991                 8       2925.0
# 2    Honda  1992                20      11875.0
# 3    Honda  1993                18      11975.0
# 4    Honda  1994                54      39650.0
# 5    Honda  1995                55      42675.0
# 6    Honda  1996                67      55875.0
# 7    Honda  1997               139     140500.0
# 8    Honda  1998               214     277250.0
# 9    Honda  1999               246     374425.0
# 10   Honda  2000               331     556350.0
# 11   Honda  2001               407     747150.0
# 12   Honda  2002               582    1302200.0
# 13   Honda  2003               892    2838650.0
# 14   Honda  2004               720    2522750.0
# 15   Honda  2005               756    3407220.0
# 16   Honda  2006               809    4634525.0
# 17   Honda  2007              1215    8501850.0
# 18   Honda  2008              1254   10334875.0
# 19   Honda  2009               948    9269700.0
# 20   Honda  2010              1037   11172100.0
# 21   Honda  2011              1416   19811925.0
# 22   Honda  2012              6652   98141550.0
# 23   Honda  2013              1811   32455879.0
# 24   Honda  2014               847   17169225.0
# 25   Honda  2015                29     615650.0
# 26  Nissan  1990                 3       4000.0
# 27  Nissan  1991                 1        400.0
# 28  Nissan  1992                 1        350.0
# 29  Nissan  1993                 7       3275.0
# 30  Nissan  1994                10       6150.0
# 31  Nissan  1995                39      23050.0
# 32  Nissan  1996                58      37325.0
# 33  Nissan  1997                81      68500.0
# 34  Nissan  1998                80      75750.0
# 35  Nissan  1999                98     105525.0
# 36  Nissan  2000               228     358334.0
# 37  Nissan  2001               217     391175.0
# 38  Nissan  2002               433     957650.0
# 39  Nissan  2003               566    1548925.0
# 40  Nissan  2004               912    3577950.0
# 41  Nissan  2005              1366    5932805.0
# 42  Nissan  2006              1330    6852300.0
# 43  Nissan  2007              1356    8002950.0
# 44  Nissan  2008              1052    7670845.0
# 45  Nissan  2009               971    8484650.0
# 46  Nissan  2010              1176   12129900.0
# 47  Nissan  2011              4940   67384914.0
# 48  Nissan  2012             10841  140262626.0
# 49  Nissan  2013              7223  104471011.0
# 50  Nissan  2014              3562   53485778.0
# 51  Nissan  2015               265    3915150.0
# 52  Toyota  1990                 8       3225.0
# 53  Toyota  1991                13       5600.0
# 54  Toyota  1992                27      18475.0
# 55  Toyota  1993                40      24575.0
# 56  Toyota  1994                51      41750.0
# 57  Toyota  1995                98      76575.0
# 58  Toyota  1996               117     119050.0
# 59  Toyota  1997               138     203100.0
# 60  Toyota  1998               216     311550.0
# 61  Toyota  1999               269     471075.0
# 62  Toyota  2000               346     775500.0
# 63  Toyota  2001               359    1059875.0
# 64  Toyota  2002               591    2054625.0
# 65  Toyota  2003               744    3205375.0
# 66  Toyota  2004               912    4691850.0
# 67  Toyota  2005              1030    5637650.0
# 68  Toyota  2006              1154    7524275.0
# 69  Toyota  2007              1549   11942925.0
# 70  Toyota  2008              1250   12869500.0
# 71  Toyota  2009              1399   12203280.0
# 72  Toyota  2010              1566   17740930.0
# 73  Toyota  2011              3169   45456781.0
# 74  Toyota  2012              4344   67348764.0
# 75  Toyota  2013              4405   70992404.0
# 76  Toyota  2014              3671   63219952.0
# 77  Toyota  2015                26     449350.0
